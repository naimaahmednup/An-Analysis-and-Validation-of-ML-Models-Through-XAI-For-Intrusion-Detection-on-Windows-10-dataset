# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# We will read our CSV file from our Google Drive and store it in a variable called windowsData
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/datasets/Windows_processed/windows10_dataset.csv')
# Out:
# Mounted at /content/drive

# %%
# df = pd.read_csv('C:\\Users\\mubah\\Desktop\\Thesis\\windows10_dataset.csv')
# print(df.shape)
# df.head()
# Out:
# (35975, 127)
#            ts  Processor_DPC_Rate Processor_pct_ Idle_Time  \
# 0  1554206309                   4              29.90817156
# 1  1554206319                   9              31.75168186
# 2  1554206329                   5              29.49516707
# 3  1554206339                  12              18.22437505
# 4  1554206349                  12              14.86118688
#
#   Processor_pct_ C3_Time Processor_pct_ Interrupt_Time Processor_pct_ C2_Time  \
# 0                      0                   0.078240397                      0
# 1                      0                   0.312520973                      0
# 2                      0                    1.16822183                      0
# 3                      0                   1.097191902                      0
# 4                      0                   1.562431019                      0
#
#   Processor_pct_ User_Time Processor_pct_ C1_Time  \
# 0              61.02750947            29.90817156
# 1              59.14459419            31.75168186
# 2              46.02794011            29.49516707
# 3              47.80621859            18.22437505
# 4               41.8731513            14.86118688
#
#   Processor_pct_ Processor_Time Processor_C1_ransitions_sec  ...  \
# 0                    66.2001486                 480.0949912  ...
# 1                   66.24773489                 427.0412837  ...
# 2                   66.90038148                 1159.426821  ...
# 3                   79.54520811                  736.622011  ...
# 4                   82.73513724                 896.1085985  ...
#
#   LogicalDisk(_Total) Avg  Disk Write Queue Length  \
# 0                                      0.134876119
# 1                                      0.157564294
# 2                                      0.401773775
# 3                                      0.259062331
# 4                                      0.103836186
#
#   LogicalDisk(_Total) Avg  Disk Queue Length  \
# 0                                0.163098103
# 1                                0.189279353
# 2                                0.782471877
# 3                                0.768934004
# 4                                1.081729712
#
#   LogicalDisk(_Total) pct_ Disk Read Time  \
# 0                             2.822198461
# 1                              3.17150584
# 2                             38.06981014
# 3                             50.98716725
# 4                              97.7893526
#
#   LogicalDisk(_Total) Disk Write Bytes sec  \
# 0                              1924988.236
# 1                              1497232.743
# 2                              1854228.536
# 3                              15912390.29
# 4                               23609299.7
#
#   LogicalDisk(_Total) Disk Transfers sec  \
# 0                            402.5827836
# 1                            355.1343322
# 2                            760.4317685
# 3                            699.4999538
# 4                            1184.550425
#
#   LogicalDisk(_Total) Avg  Disk Bytes Transfer  \
# 0                                  9100.481592
# 1                                  11153.55449
# 2                                  26994.26595
# 3                                   53141.6638
# 4                                  40988.68444
#
#    LogicalDisk(_Total) pct_ Disk Write Time  \
# 0                               13.48761188
# 1                               15.75642941
# 2                               40.17737752
# 3                               25.90623311
# 4                               10.38361856
#
#   LogicalDisk(_Total) Avg  Disk sec Transfer  label    type
# 0                                0.000405118      0  normal
# 1                                0.000532995      0  normal
# 2                                0.001028323      0  normal
# 3                                0.001099429      0  normal
# 4                                0.000912738      0  normal
#
# [5 rows x 127 columns]

# %%
df.drop(['type','ts'], inplace = True, axis = 1)

# %%
plt.figure(figsize=(30, 30))
sns.heatmap(df.corr(), annot=True, linewidth = 3, cmap='mako')

# %%
# 'Memory Pool Paged Resident Bytes', 'Memory System Driver Total Bytes', 'Memory Standby Cache Core Bytes', 'Memory Long-Term Average Standby Cache Lifetime (s)', 'Memory Pool Nonpaged Bytes', 'Memory Pool Paged Bytes',

# %%
# df.columns.values.tolist()

# %%
df = df.astype(str)

# %%
df = df[~df.applymap(lambda x: x.strip()).eq('').any(axis=1)]

# %%
# df = df[~df[['Process_IO Read_Operations_sec']].str.strip().eq('')]

# %%
print(df['Process_IO Read_Operations_sec'].str.strip().eq('').value_counts())
# Out:
# False    35214
# Name: Process_IO Read_Operations_sec, dtype: int64

# %%
# columns_with_spaces = df.columns[df.apply(lambda x: x.str.isspace().any())]
# print(columns_with_spaces)

# %%
# columns_with_spaces = windows.columns[windows.apply(lambda x: x.str.isspace().any())]
# print(columns_with_spaces)

# %%
x = df.drop('label', axis=1)
y = df['label']

from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()

rfc.fit(x,y)
fi_col = []
fi = []

for i,column in enumerate(df.drop('label', axis = 1)):
    print('The feature importance for {} is : {}'.format(column, rfc.feature_importances_[i]))

    fi_col.append(column)
    fi.append(rfc.feature_importances_[i])

fi_df = zip(fi_col, fi)
fi_df = pd.DataFrame(fi_df, columns = ['Feature','Feature Importance'])

# Ordering the data
fi_df = fi_df.sort_values('Feature Importance', ascending = False).reset_index()

# Creating columns to keep
columns_to_keep = fi_df['Feature']
# Out:
# The feature importance for Processor_DPC_Rate is : 0.0002451247045169846
# The feature importance for Processor_pct_ Idle_Time is : 0.008093914640054576
# The feature importance for Processor_pct_ C3_Time is : 0.0
# The feature importance for Processor_pct_ Interrupt_Time is : 0.010891147904300005
# The feature importance for Processor_pct_ C2_Time is : 0.0
# The feature importance for Processor_pct_ User_Time is : 0.008875534798440794
# The feature importance for Processor_pct_ C1_Time is : 0.005825052184793259
# The feature importance for Processor_pct_ Processor_Time is : 0.0056581640540211125
# The feature importance for Processor_C1_ransitions_sec is : 0.0018598567591612586
# The feature importance for Processor_pct_ DPC_Time is : 0.0006393964379016476
# The feature importance for Processor_C2_ransitions_sec is : 0.0
# The feature importance for Processor_pct_ Privileged_Time is : 0.0018218656031982318
# The feature importance for Processor_C3_ransitions_sec is : 0.0
# The feature importance for Processor_DPCs_Queued_sec is : 0.0015192403368987806
# The feature importance for Processor_Interrupts_sec is : 0.001140201386570937
# The feature importance for Process_Pool_Paged Bytes is : 0.052473329533731246
# The feature importance for Process_IO Read_Operations_sec is : 0.022705359440257124
# The feature importance for Process_Working_Set_ Private is : 0.003930585879015363
# The feature importance for Process_Working_Set_Peak is : 0.011796767287391822
# The feature importance for Process_IO_Write Operations_sec is : 0.02267339794594789
# The feature importance for Process_Page_File Bytes is : 0.006447579487119858
# The feature importance for Process_pct_ User_Time is : 0.008964926195093162
# The feature importance for Process_Virtual_Bytes Peak is : 0.05610842976810076
# The feature importance for Process_Page_File Bytes Peak is : 0.010221656905135839
# The feature importance for Process_IO_Other_Bytes_sec is : 0.001231288872306637
# The feature importance for Process_Private_Bytes is : 0.0076647625166970145
# The feature importance for Process_IO_Write_Bytes_sec is : 0.0023787869650143284
# The feature importance for Process_Elapsed_Time is : 0.0
# The feature importance for Process_Virtual_Bytes is : 0.04700350268197616
# The feature importance for Process_pct_ Processor_Time is : 0.0022910310699722166
# The feature importance for Process_Creating Process ID is : 0.0
# The feature importance for Process_Pool Nonpaged Bytes is : 0.0116250133248507
# The feature importance for Process_Working Set is : 0.016285066889707923
# The feature importance for Process_Page Faults_sec is : 0.0077543317340794
# The feature importance for Process_ID Process is : 0.0
# The feature importance for Process_IO Other Operations_sec is : 0.005966364277736496
# The feature importance for Process_IO Data Operations_sec is : 0.02735341582079538
# The feature importance for Process_Thread Count is : 0.03936146321124998
# The feature importance for Process_pct_ Privileged_Time is : 0.0026938011060974342
# The feature importance for Process_IO Data Bytes_sec is : 0.004617372027838616
# The feature importance for Process_IO Read Bytes_sec is : 0.03189628294347
# The feature importance for Process_Priority Base is : 0.0
# The feature importance for Process_Handle Count is : 0.0501254043801645
# The feature importance for Network_I(Intel R _82574L_GNC)TCP_APS is : 0.03153646775050181
# The feature importance for Network_I(Intel R _82574L_GNC) Packets Received Unknown is : 0.0
# The feature importance for Network_I(Intel R _82574L_GNC) Bytes Received sec is : 0.0032164109347178915
# The feature importance for Network_I(Intel R _82574L_GNC) Bytes Sent sec is : 0.00410429306817344
# The feature importance for Network_I(Intel R _82574L_GNC) Packets Outbound Errors is : 0.0
# The feature importance for Network_I(Intel R _82574L_GNC) Packets Received Discarded is : 0.0
# The feature importance for Network_I(Intel R _82574L_GNC) Bytes Total sec is : 0.005159365793512489
# The feature importance for Network_I(Intel R _82574L_GNC) Packets Outbound Discarded is : 0.0
# The feature importance for Network_I(Intel R _82574L_GNC) TCP RSC Exceptions sec is : 0.0
# The feature importance for Network_I(Intel R _82574L_GNC) Packets Sent Unicast sec is : 0.00515185473453071
# The feature importance for Network_I(Intel R _82574L_GNC) Output Queue Length is : 0.0
# The feature importance for Network_I(Intel R _82574L_GNC) Packets Received sec is : 0.004449894582345201
# The feature importance for Network_I(Intel R _82574L_GNC) Current Bandwidth is : 0.0
# The feature importance for Network_I(Intel R _82574L_GNC) Packets sec is : 0.0024577266595362727
# The feature importance for Network_I(Intel R _82574L_GNC) TCP Active RSC Connections is : 0.010673484541569581
# The feature importance for Network_I(Intel R _82574L_GNC) Packets Sent sec is : 0.0027281655950229613
# The feature importance for Network_I(Intel R _82574L_GNC) Packets Received Unicast sec is : 0.0031000433535679343
# The feature importance for Network_I(Intel R _82574L_GNC) Packets Sent Non-Unicast sec is : 0.0
# The feature importance for Network_I(Intel R _82574L_GNC) Packets Received Non-Unicast sec is : 0.0
# The feature importance for Network_I(Intel R _82574L_GNC) TCP RSC Coalesced Packets sec is : 0.0
# The feature importance for Network_I(Intel R _82574L_GNC) Offloaded Connections is : 0.0
# The feature importance for Network_I(Intel R _82574L_GNC) Packets Received Errors is : 0.0
# The feature importance for Memory Pool Paged Bytes is : 0.022142033809605156
# The feature importance for Memory Free & Zero Page List Bytes is : 0.004767238078436059
# The feature importance for Memory Cache Bytes Peak is : 0.030491937783805233
# The feature importance for Memory System Code Resident Bytes is : 0.0006167794561828297
# The feature importance for Memory Available Bytes is : 0.0015591570611725566
# The feature importance for Memory Commit Limit is : 0.004033656371001875
# The feature importance for Memory Transition Pages RePurposed sec is : 7.080177317894935e-05
# The feature importance for Memory Pages Output sec is : 1.3366472934132085e-05
# The feature importance for Memory Page Reads sec is : 0.0005501177648979174
# The feature importance for Memory Demand Zero Faults sec is : 0.004497419352588042
# The feature importance for Memory Available KBytes is : 0.002526101083871409
# The feature importance for Memory Pages sec is : 0.0005231147064379649
# The feature importance for Memory Cache Bytes is : 0.00778033288223371
# The feature importance for Memory Pool Nonpaged Bytes is : 0.036316460823766654
# The feature importance for Memory Page Faults sec is : 0.004209298519537694
# The feature importance for Memory Transition Faults sec is : 0.002168631614541347
# The feature importance for Memory System Cache Resident Bytes is : 0.019264205799813076
# The feature importance for Memory Long-Term Average Standby Cache Lifetime (s) is : 0.01404980360461729
# The feature importance for Memory Standby Cache Reserve Bytes is : 0.0030047074048764814
# The feature importance for Memory Page Writes sec is : 0.0001701352118118774
# The feature importance for Memory System Code Total Bytes is : 2.0808493061126522e-05
# The feature importance for Memory Standby Cache Core Bytes is : 0.05689998988986713
# The feature importance for Memory System Driver Resident Bytes is : 0.012344753624518895
# The feature importance for Memory Standby Cache Normal Priority Bytes is : 0.02014910395794654
# The feature importance for Memory Pool Paged Allocs is : 5.958529613634115e-05
# The feature importance for Memory Pool Nonpaged Allocs is : 5.341036805543309e-05
# The feature importance for Memory pct_ Committed Bytes In Use is : 0.00603219380483682
# The feature importance for Memory Free System Page Table Entries is : 0.02477850249827147
# The feature importance for Memory Available MBytes is : 0.00313198538160183
# The feature importance for Memory Modified Page List Bytes is : 0.0020966816909659724
# The feature importance for Memory Cache Faults sec is : 0.0017009131690623408
# The feature importance for Memory Committed Bytes is : 0.0078925237516433
# The feature importance for Memory System Driver Total Bytes is : 0.02128029680180865
# The feature importance for Memory Pages Input sec is : 0.0005683255211734994
# The feature importance for Memory Pool Paged Resident Bytes is : 0.022774202375940234
# The feature importance for Memory Write Copies sec is : 0.0010289063947322742
# The feature importance for LogicalDisk(_Total) Avg  Disk Bytes Write is : 0.0010847179340871685
# The feature importance for LogicalDisk(_Total) pct_ Idle Time is : 0.0008306587723804925
# The feature importance for LogicalDisk(_Total) Disk Reads sec is : 0.00031087930088941274
# The feature importance for LogicalDisk(_Total) pct_ Free Space is : 0.03544518299053973
# The feature importance for LogicalDisk(_Total) Disk Read Bytes sec is : 0.0004060783878333389
# The feature importance for LogicalDisk(_Total) Avg  Disk sec Read is : 0.0004344863709557213
# The feature importance for LogicalDisk(_Total) Disk Writes sec is : 0.0010688216890672375
# The feature importance for LogicalDisk(_Total) Current Disk Queue Length is : 5.229981099971767e-05
# The feature importance for LogicalDisk(_Total) Split IO Sec is : 0.0006105952874022408
# The feature importance for LogicalDisk(_Total) Free Megabytes is : 0.033535979019000364
# The feature importance for LogicalDisk(_Total) Avg  Disk sec Write is : 0.0008841414246506821
# The feature importance for LogicalDisk(_Total) Disk Bytes sec is : 0.0011812380964899894
# The feature importance for LogicalDisk(_Total) Avg  Disk Read Queue Length is : 0.0003166047190065404
# The feature importance for LogicalDisk(_Total) pct_ Disk Time is : 0.002052097438576999
# The feature importance for LogicalDisk(_Total) Avg  Disk Bytes Read is : 0.00032110876563762694
# The feature importance for LogicalDisk(_Total) Avg  Disk Write Queue Length is : 0.00185043912207253
# The feature importance for LogicalDisk(_Total) Avg  Disk Queue Length is : 0.0009009400659714089
# The feature importance for LogicalDisk(_Total) pct_ Disk Read Time is : 0.0018318256582092287
# The feature importance for LogicalDisk(_Total) Disk Write Bytes sec is : 0.0008986753290501471
# The feature importance for LogicalDisk(_Total) Disk Transfers sec is : 0.0011104865692474486
# The feature importance for LogicalDisk(_Total) Avg  Disk Bytes Transfer is : 0.0007733945611584106
# The feature importance for LogicalDisk(_Total) pct_ Disk Write Time is : 0.000897261863772902
# The feature importance for LogicalDisk(_Total) Avg  Disk sec Transfer is : 0.0009174781409829029

# %%
pd.set_option('display.max_rows', 124)
fi_df.head(124)
# Out:
#      index                                            Feature  \
# 0       15                           Process_Pool_Paged Bytes
# 1       43              Network_I(Intel R _82574L_GNC)TCP_APS
# 2       42                               Process_Handle Count
# 3       78                         Memory Pool Nonpaged Bytes
# 4       86                    Memory Standby Cache Core Bytes
# 5       37                               Process_Thread Count
# 6      104                LogicalDisk(_Total) pct_ Free Space
# 7       92              Memory Free System Page Table Entries
# 8       28                              Process_Virtual_Bytes
# 9      110                 LogicalDisk(_Total) Free Megabytes
# 10      22                         Process_Virtual_Bytes Peak
# 11      40                          Process_IO Read Bytes_sec
# 12      81                 Memory System Cache Resident Bytes
# 13      19                    Process_IO_Write Operations_sec
# 14      67                            Memory Cache Bytes Peak
# 15      16                     Process_IO Read_Operations_sec
# 16      99                   Memory Pool Paged Resident Bytes
# 17      97                   Memory System Driver Total Bytes
# 18      36                     Process_IO Data Operations_sec
# 19      65                            Memory Pool Paged Bytes
# 20      82  Memory Long-Term Average Standby Cache Lifetim...
# 21      31                        Process_Pool Nonpaged Bytes
# 22      32                                Process_Working Set
# 23      57  Network_I(Intel R _82574L_GNC) TCP Active RSC ...
# 24      96                             Memory Committed Bytes
# 25      77                                 Memory Cache Bytes
# 26      87                Memory System Driver Resident Bytes
# 27      88         Memory Standby Cache Normal Priority Bytes
# 28      18                           Process_Working_Set_Peak
# 29      39                          Process_IO Data Bytes_sec
# 30      59  Network_I(Intel R _82574L_GNC) Packets Receive...
# 31      91                 Memory pct_ Committed Bytes In Use
# 32      46      Network_I(Intel R _82574L_GNC) Bytes Sent sec
# 33      56         Network_I(Intel R _82574L_GNC) Packets sec
# 34      21                             Process_pct_ User_Time
# 35      23                       Process_Page_File Bytes Peak
# 36      54  Network_I(Intel R _82574L_GNC) Packets Receive...
# 37      70                                Memory Commit Limit
# 38      52  Network_I(Intel R _82574L_GNC) Packets Sent Un...
# 39      25                              Process_Private_Bytes
# 40      20                            Process_Page_File Bytes
# 41      45  Network_I(Intel R _82574L_GNC) Bytes Received sec
# 42      35                    Process_IO Other Operations_sec
# 43      38                       Process_pct_ Privileged_Time
# 44      24                         Process_IO_Other_Bytes_sec
# 45       5                           Processor_pct_ User_Time
# 46       3                      Processor_pct_ Interrupt_Time
# 47      83                 Memory Standby Cache Reserve Bytes
# 48      17                       Process_Working_Set_ Private
# 49       1                           Processor_pct_ Idle_Time
# 50      66                 Memory Free & Zero Page List Bytes
# 51       7                      Processor_pct_ Processor_Time
# 52      79                             Memory Page Faults sec
# 53      69                             Memory Available Bytes
# 54      49     Network_I(Intel R _82574L_GNC) Bytes Total sec
# 55      11                     Processor_pct_ Privileged_Time
# 56      80                       Memory Transition Faults sec
# 57      75                            Memory Available KBytes
# 58      74                      Memory Demand Zero Faults sec
# 59      58    Network_I(Intel R _82574L_GNC) Packets Sent sec
# 60      84                             Memory Page Writes sec
# 61      26                         Process_IO_Write_Bytes_sec
# 62      95                            Memory Cache Faults sec
# 63      13                          Processor_DPCs_Queued_sec
# 64      93                            Memory Available MBytes
# 65       6                             Processor_pct_ C1_Time
# 66       9                            Processor_pct_ DPC_Time
# 67       8                        Processor_C1_ransitions_sec
# 68      94                    Memory Modified Page List Bytes
# 69      33                            Process_Page Faults_sec
# 70      14                           Processor_Interrupts_sec
# 71     102                 LogicalDisk(_Total) pct_ Idle Time
# 72     117         LogicalDisk(_Total) Avg  Disk Queue Length
# 73     101          LogicalDisk(_Total) Avg  Disk Bytes Write
# 74     114                 LogicalDisk(_Total) pct_ Disk Time
# 75      29                        Process_pct_ Processor_Time
# 76     116   LogicalDisk(_Total) Avg  Disk Write Queue Length
# 77     123         LogicalDisk(_Total) Avg  Disk sec Transfer
# 78     122           LogicalDisk(_Total) pct_ Disk Write Time
# 79     111            LogicalDisk(_Total) Avg  Disk sec Write
# 80     121       LogicalDisk(_Total) Avg  Disk Bytes Transfer
# 81     107                LogicalDisk(_Total) Disk Writes sec
# 82     112                 LogicalDisk(_Total) Disk Bytes sec
# 83     100                            Memory Write Copies sec
# 84     119           LogicalDisk(_Total) Disk Write Bytes sec
# 85     120             LogicalDisk(_Total) Disk Transfers sec
# 86      68                  Memory System Code Resident Bytes
# 87      73                              Memory Page Reads sec
# 88      89                           Memory Pool Paged Allocs
# 89     113    LogicalDisk(_Total) Avg  Disk Read Queue Length
# 90      76                                   Memory Pages sec
# 91     109                   LogicalDisk(_Total) Split IO Sec
# 92      98                             Memory Pages Input sec
# 93     106             LogicalDisk(_Total) Avg  Disk sec Read
# 94     118            LogicalDisk(_Total) pct_ Disk Read Time
# 95     105            LogicalDisk(_Total) Disk Read Bytes sec
# 96     103                 LogicalDisk(_Total) Disk Reads sec
# 97     115           LogicalDisk(_Total) Avg  Disk Bytes Read
# 98       0                                 Processor_DPC_Rate
# 99      71             Memory Transition Pages RePurposed sec
# 100    108      LogicalDisk(_Total) Current Disk Queue Length
# 101     72                            Memory Pages Output sec
# 102     90                        Memory Pool Nonpaged Allocs
# 103     47  Network_I(Intel R _82574L_GNC) Packets Outboun...
# 104      2                             Processor_pct_ C3_Time
# 105      4                             Processor_pct_ C2_Time
# 106     10                        Processor_C2_ransitions_sec
# 107     12                        Processor_C3_ransitions_sec
# 108     27                               Process_Elapsed_Time
# 109     30                        Process_Creating Process ID
# 110     34                                 Process_ID Process
# 111     41                              Process_Priority Base
# 112     44  Network_I(Intel R _82574L_GNC) Packets Receive...
# 113     50  Network_I(Intel R _82574L_GNC) Packets Outboun...
# 114     48  Network_I(Intel R _82574L_GNC) Packets Receive...
# 115     85                     Memory System Code Total Bytes
# 116     51  Network_I(Intel R _82574L_GNC) TCP RSC Excepti...
# 117     53  Network_I(Intel R _82574L_GNC) Output Queue Le...
# 118     55   Network_I(Intel R _82574L_GNC) Current Bandwidth
# 119     60  Network_I(Intel R _82574L_GNC) Packets Sent No...
# 120     61  Network_I(Intel R _82574L_GNC) Packets Receive...
# 121     63  Network_I(Intel R _82574L_GNC) Offloaded Conne...
# 122     64  Network_I(Intel R _82574L_GNC) Packets Receive...
# 123     62  Network_I(Intel R _82574L_GNC) TCP RSC Coalesc...
#
#      Feature Importance
# 0              0.066620
# 1              0.055416
# 2              0.053420
# 3              0.047787
# 4              0.046699
# 5              0.044607
# 6              0.040947
# 7              0.037041
# 8              0.034840
# 9              0.031907
# 10             0.031330
# 11             0.025871
# 12             0.023981
# 13             0.021716
# 14             0.020639
# 15             0.020620
# 16             0.019340
# 17             0.017646
# 18             0.017251
# 19             0.016506
# 20             0.014637
# 21             0.014362
# 22             0.012862
# 23             0.012346
# 24             0.011638
# 25             0.011638
# 26             0.011463
# 27             0.011161
# 28             0.010804
# 29             0.010623
# 30             0.010587
# 31             0.009960
# 32             0.009894
# 33             0.008430
# 34             0.008386
# 35             0.007628
# 36             0.007258
# 37             0.006930
# 38             0.006195
# 39             0.006162
# 40             0.005969
# 41             0.005593
# 42             0.005540
# 43             0.005212
# 44             0.005103
# 45             0.004915
# 46             0.004795
# 47             0.004591
# 48             0.004522
# 49             0.004465
# 50             0.004175
# 51             0.003977
# 52             0.003611
# 53             0.003121
# 54             0.003042
# 55             0.002998
# 56             0.002812
# 57             0.002682
# 58             0.002596
# 59             0.002436
# 60             0.002241
# 61             0.002225
# 62             0.002049
# 63             0.001974
# 64             0.001877
# 65             0.001862
# 66             0.001798
# 67             0.001749
# 68             0.001698
# 69             0.001638
# 70             0.001506
# 71             0.001267
# 72             0.001246
# 73             0.001144
# 74             0.001029
# 75             0.000953
# 76             0.000919
# 77             0.000915
# 78             0.000905
# 79             0.000895
# 80             0.000868
# 81             0.000853
# 82             0.000845
# 83             0.000805
# 84             0.000782
# 85             0.000763
# 86             0.000737
# 87             0.000613
# 88             0.000600
# 89             0.000562
# 90             0.000473
# 91             0.000441
# 92             0.000421
# 93             0.000411
# 94             0.000320
# 95             0.000305
# 96             0.000299
# 97             0.000288
# 98             0.000265
# 99             0.000085
# 100            0.000038
# 101            0.000034
# 102            0.000001
# 103            0.000000
# 104            0.000000
# 105            0.000000
# 106            0.000000
# 107            0.000000
# 108            0.000000
# 109            0.000000
# 110            0.000000
# 111            0.000000
# 112            0.000000
# 113            0.000000
# 114            0.000000
# 115            0.000000
# 116            0.000000
# 117            0.000000
# 118            0.000000
# 119            0.000000
# 120            0.000000
# 121            0.000000
# 122            0.000000
# 123            0.000000

# %%
pd.set_option('display.max_rows', 124)
fi_df.head(124)
# Out:
#      index                                            Feature  \
# 0       15                           Process_Pool_Paged Bytes
# 1       42                               Process_Handle Count
# 2       92              Memory Free System Page Table Entries
# 3       37                               Process_Thread Count
# 4      110                 LogicalDisk(_Total) Free Megabytes
# 5       28                              Process_Virtual_Bytes
# 6       22                         Process_Virtual_Bytes Peak
# 7      104                LogicalDisk(_Total) pct_ Free Space
# 8       78                         Memory Pool Nonpaged Bytes
# 9       86                    Memory Standby Cache Core Bytes
# 10      43              Network_I(Intel R _82574L_GNC)TCP_APS
# 11      40                          Process_IO Read Bytes_sec
# 12      36                     Process_IO Data Operations_sec
# 13      97                   Memory System Driver Total Bytes
# 14      81                 Memory System Cache Resident Bytes
# 15      65                            Memory Pool Paged Bytes
# 16      67                            Memory Cache Bytes Peak
# 17      99                   Memory Pool Paged Resident Bytes
# 18      19                    Process_IO_Write Operations_sec
# 19      87                Memory System Driver Resident Bytes
# 20      32                                Process_Working Set
# 21      46      Network_I(Intel R _82574L_GNC) Bytes Sent sec
# 22      16                     Process_IO Read_Operations_sec
# 23      88         Memory Standby Cache Normal Priority Bytes
# 24      18                           Process_Working_Set_Peak
# 25      31                        Process_Pool Nonpaged Bytes
# 26      82  Memory Long-Term Average Standby Cache Lifetim...
# 27      96                             Memory Committed Bytes
# 28       3                      Processor_pct_ Interrupt_Time
# 29      57  Network_I(Intel R _82574L_GNC) TCP Active RSC ...
# 30      58    Network_I(Intel R _82574L_GNC) Packets Sent sec
# 31      23                       Process_Page_File Bytes Peak
# 32      21                             Process_pct_ User_Time
# 33      91                 Memory pct_ Committed Bytes In Use
# 34      35                    Process_IO Other Operations_sec
# 35      77                                 Memory Cache Bytes
# 36      83                 Memory Standby Cache Reserve Bytes
# 37      20                            Process_Page_File Bytes
# 38      38                       Process_pct_ Privileged_Time
# 39      70                                Memory Commit Limit
# 40      45  Network_I(Intel R _82574L_GNC) Bytes Received sec
# 41      52  Network_I(Intel R _82574L_GNC) Packets Sent Un...
# 42      59  Network_I(Intel R _82574L_GNC) Packets Receive...
# 43      25                              Process_Private_Bytes
# 44      54  Network_I(Intel R _82574L_GNC) Packets Receive...
# 45      39                          Process_IO Data Bytes_sec
# 46      26                         Process_IO_Write_Bytes_sec
# 47      33                            Process_Page Faults_sec
# 48      49     Network_I(Intel R _82574L_GNC) Bytes Total sec
# 49      17                       Process_Working_Set_ Private
# 50      56         Network_I(Intel R _82574L_GNC) Packets sec
# 51       5                           Processor_pct_ User_Time
# 52       1                           Processor_pct_ Idle_Time
# 53       7                      Processor_pct_ Processor_Time
# 54      74                      Memory Demand Zero Faults sec
# 55      69                             Memory Available Bytes
# 56      29                        Process_pct_ Processor_Time
# 57      66                 Memory Free & Zero Page List Bytes
# 58       6                             Processor_pct_ C1_Time
# 59      93                            Memory Available MBytes
# 60       8                        Processor_C1_ransitions_sec
# 61      13                          Processor_DPCs_Queued_sec
# 62      79                             Memory Page Faults sec
# 63      75                            Memory Available KBytes
# 64      94                    Memory Modified Page List Bytes
# 65      11                     Processor_pct_ Privileged_Time
# 66      80                       Memory Transition Faults sec
# 67     116   LogicalDisk(_Total) Avg  Disk Write Queue Length
# 68      14                           Processor_Interrupts_sec
# 69     120             LogicalDisk(_Total) Disk Transfers sec
# 70      24                         Process_IO_Other_Bytes_sec
# 71      95                            Memory Cache Faults sec
# 72     121       LogicalDisk(_Total) Avg  Disk Bytes Transfer
# 73      89                           Memory Pool Paged Allocs
# 74     117         LogicalDisk(_Total) Avg  Disk Queue Length
# 75     112                 LogicalDisk(_Total) Disk Bytes sec
# 76     111            LogicalDisk(_Total) Avg  Disk sec Write
# 77     119           LogicalDisk(_Total) Disk Write Bytes sec
# 78     114                 LogicalDisk(_Total) pct_ Disk Time
# 79     102                 LogicalDisk(_Total) pct_ Idle Time
# 80     122           LogicalDisk(_Total) pct_ Disk Write Time
# 81     123         LogicalDisk(_Total) Avg  Disk sec Transfer
# 82     107                LogicalDisk(_Total) Disk Writes sec
# 83     113    LogicalDisk(_Total) Avg  Disk Read Queue Length
# 84     100                            Memory Write Copies sec
# 85     101          LogicalDisk(_Total) Avg  Disk Bytes Write
# 86      73                              Memory Page Reads sec
# 87      76                                   Memory Pages sec
# 88       9                            Processor_pct_ DPC_Time
# 89      98                             Memory Pages Input sec
# 90     105            LogicalDisk(_Total) Disk Read Bytes sec
# 91     109                   LogicalDisk(_Total) Split IO Sec
# 92     106             LogicalDisk(_Total) Avg  Disk sec Read
# 93     103                 LogicalDisk(_Total) Disk Reads sec
# 94     118            LogicalDisk(_Total) pct_ Disk Read Time
# 95      85                     Memory System Code Total Bytes
# 96     115           LogicalDisk(_Total) Avg  Disk Bytes Read
# 97       0                                 Processor_DPC_Rate
# 98      71             Memory Transition Pages RePurposed sec
# 99      68                  Memory System Code Resident Bytes
# 100     72                            Memory Pages Output sec
# 101    108      LogicalDisk(_Total) Current Disk Queue Length
# 102     84                             Memory Page Writes sec
# 103     90                        Memory Pool Nonpaged Allocs
# 104     44  Network_I(Intel R _82574L_GNC) Packets Receive...
# 105      2                             Processor_pct_ C3_Time
# 106      4                             Processor_pct_ C2_Time
# 107     10                        Processor_C2_ransitions_sec
# 108     12                        Processor_C3_ransitions_sec
# 109     27                               Process_Elapsed_Time
# 110     30                        Process_Creating Process ID
# 111     34                                 Process_ID Process
# 112     41                              Process_Priority Base
# 113     50  Network_I(Intel R _82574L_GNC) Packets Outboun...
# 114     47  Network_I(Intel R _82574L_GNC) Packets Outboun...
# 115     48  Network_I(Intel R _82574L_GNC) Packets Receive...
# 116     51  Network_I(Intel R _82574L_GNC) TCP RSC Excepti...
# 117     53  Network_I(Intel R _82574L_GNC) Output Queue Le...
# 118     55   Network_I(Intel R _82574L_GNC) Current Bandwidth
# 119     60  Network_I(Intel R _82574L_GNC) Packets Sent No...
# 120     61  Network_I(Intel R _82574L_GNC) Packets Receive...
# 121     63  Network_I(Intel R _82574L_GNC) Offloaded Conne...
# 122     64  Network_I(Intel R _82574L_GNC) Packets Receive...
# 123     62  Network_I(Intel R _82574L_GNC) TCP RSC Coalesc...
#
#      Feature Importance
# 0              0.073885
# 1              0.053222
# 2              0.047302
# 3              0.046466
# 4              0.043577
# 5              0.043064
# 6              0.039752
# 7              0.036262
# 8              0.034564
# 9              0.034261
# 10             0.027910
# 11             0.026414
# 12             0.025850
# 13             0.024465
# 14             0.023773
# 15             0.023307
# 16             0.020850
# 17             0.019185
# 18             0.018319
# 19             0.017216
# 20             0.016326
# 21             0.013986
# 22             0.013785
# 23             0.013281
# 24             0.013090
# 25             0.011851
# 26             0.011134
# 27             0.011088
# 28             0.010698
# 29             0.010268
# 30             0.008724
# 31             0.008278
# 32             0.007865
# 33             0.007092
# 34             0.006987
# 35             0.006974
# 36             0.006734
# 37             0.006164
# 38             0.006116
# 39             0.006093
# 40             0.006041
# 41             0.006039
# 42             0.005843
# 43             0.005834
# 44             0.005744
# 45             0.005262
# 46             0.004374
# 47             0.004317
# 48             0.004269
# 49             0.004193
# 50             0.004118
# 51             0.003531
# 52             0.003504
# 53             0.003483
# 54             0.003359
# 55             0.003280
# 56             0.003131
# 57             0.002973
# 58             0.002901
# 59             0.002444
# 60             0.002359
# 61             0.002216
# 62             0.002151
# 63             0.002111
# 64             0.001919
# 65             0.001874
# 66             0.001779
# 67             0.001725
# 68             0.001494
# 69             0.001339
# 70             0.001288
# 71             0.001044
# 72             0.001035
# 73             0.000997
# 74             0.000958
# 75             0.000947
# 76             0.000923
# 77             0.000907
# 78             0.000889
# 79             0.000854
# 80             0.000849
# 81             0.000836
# 82             0.000826
# 83             0.000733
# 84             0.000713
# 85             0.000691
# 86             0.000680
# 87             0.000658
# 88             0.000635
# 89             0.000619
# 90             0.000522
# 91             0.000487
# 92             0.000393
# 93             0.000359
# 94             0.000304
# 95             0.000302
# 96             0.000268
# 97             0.000224
# 98             0.000098
# 99             0.000086
# 100            0.000033
# 101            0.000033
# 102            0.000018
# 103            0.000001
# 104            0.000000
# 105            0.000000
# 106            0.000000
# 107            0.000000
# 108            0.000000
# 109            0.000000
# 110            0.000000
# 111            0.000000
# 112            0.000000
# 113            0.000000
# 114            0.000000
# 115            0.000000
# 116            0.000000
# 117            0.000000
# 118            0.000000
# 119            0.000000
# 120            0.000000
# 121            0.000000
# 122            0.000000
# 123            0.000000

# %% [markdown]
# **Feature importance based on random forest**

# %%
df = df.loc[:, ['LogicalDisk(_Total) Free Megabytes' , 'LogicalDisk(_Total) pct_ Free Space' , 'Memory Pool Paged Resident Bytes', 'Memory System Driver Total Bytes' ,'Memory Committed Bytes' , 'Memory Free System Page Table Entries', 'Memory Standby Cache Core Bytes','Memory System Driver Resident Bytes','Memory Standby Cache Normal Priority Bytes', 'Memory Long-Term Average Standby Cache Lifetime (s)', 'Memory Free System Page Table Entries','Memory System Cache Resident Bytes' , 'Memory Pool Nonpaged Bytes', 'Memory Cache Bytes', 'Memory Pool Paged Bytes','Memory Cache Bytes Peak', 'Network_I(Intel R _82574L_GNC) Bytes Sent sec' ,'Network_I(Intel R _82574L_GNC)TCP_APS','Process_IO Read Bytes_sec','Process_Handle Count','Process_IO Data Operations_sec','Process_Thread Count','Process_Pool Nonpaged Bytes','Process_Working Set','Process_Virtual_Bytes','Process_pct_ User_Time','Process_Virtual_Bytes Peak','Process_Working_Set_Peak','Process_IO_Write Operations_sec' ,'Process_Pool_Paged Bytes','Process_IO Read_Operations_sec', 'label' ]]

# %%
df = df.astype(float)

# %%
plt.figure(figsize=(30, 30))
sns.heatmap(df.corr(), annot=True, linewidth = 3, cmap='mako')

# %%
df.drop('Memory Free System Page Table Entries', inplace = True, axis = 1)

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(df.corr(), annot=True, linewidth = 3, cmap='mako')

# %%
# df = df.loc[:, ['Memory Pool Paged Resident Bytes','Memory System Driver Total Bytes', 'Memory Standby Cache Core Bytes', 'Memory Long-Term Average Standby Cache Lifetime (s)','Memory Pool Nonpaged Bytes','Memory Pool Paged Bytes','Network_I(Intel R _82574L_GNC) Bytes Sent sec' ,'Network_I(Intel R _82574L_GNC)TCP_APS', 'Process_Handle Count','Process_Thread Count','Process_Working Set','Process_Virtual_Bytes','Process_Virtual_Bytes Peak','Process_Working_Set_Peak', 'Process_Pool_Paged Bytes', 'label']]
# #---corelation heatmap----
# import seaborn as sns
# plt.figure(figsize=(20, 15))
# sns.heatmap(df.corr(), annot=True, linewidth = 3, cmap='mako')

# %%
# import matplotlib.pyplot as plt
# columns = df.columns
# for col in columns:
#     print("col: ", col)
#     plt.scatter(df.index, df[col])
#     plt.show()

# %%
df.drop(['Memory System Driver Total Bytes',
'Memory System Driver Resident Bytes',
'Memory System Cache Resident Bytes',
'Memory Pool Nonpaged Bytes',
'Memory Pool Paged Bytes',
'Memory Cache Bytes Peak',
'Network_I(Intel R _82574L_GNC)TCP_APS',
'Process_Handle Count',
'Process_Thread Count',
'Process_Working Set',
'Process_Virtual_Bytes',
'Process_Virtual_Bytes Peak',
'Process_Working_Set_Peak',
'Process_Pool_Paged Bytes'], inplace = True, axis = 1)

# %%
# import matplotlib.pyplot as plt
# columns = df.columns
# for col in columns:
#     print("col: ", col)
#     plt.scatter(df.index, df[col])
#     plt.show()

# %%
df.head()
# Out:
#    LogicalDisk(_Total) Free Megabytes  LogicalDisk(_Total) pct_ Free Space  \
# 0                            167984.0                            82.156219
# 1                            167984.0                            82.156219
# 2                            167984.0                            82.156219
# 3                            167984.0                            82.156219
# 4                            167984.0                            82.156219
#
#    Memory Pool Paged Resident Bytes  Memory Committed Bytes  \
# 0                        83619840.0            3.460387e+09
# 1                        83984384.0            3.459990e+09
# 2                        79081472.0            3.522941e+09
# 3                        52133888.0            3.688444e+09
# 4                        29245440.0            3.688333e+09
#
#    Memory Standby Cache Core Bytes  \
# 0                      157052928.0
# 1                      157036544.0
# 2                      113893376.0
# 3                        2453504.0
# 4                        2338816.0
#
#    Memory Standby Cache Normal Priority Bytes  \
# 0                                  95240192.0
# 1                                  94769152.0
# 2                                  23834624.0
# 3                                  63152128.0
# 4                                  52461568.0
#
#    Memory Long-Term Average Standby Cache Lifetime (s)  Memory Cache Bytes  \
# 0                                               48.0            18944000.0
# 1                                               48.0            16445440.0
# 2                                               46.0            14024704.0
# 3                                               29.0             5312512.0
# 4                                               31.0             2392064.0
#
#    Network_I(Intel R _82574L_GNC) Bytes Sent sec  Process_IO Read Bytes_sec  \
# 0                                     221.720966               8.755815e+04
# 1                                     210.620362               7.339650e+04
# 2                                     209.808634               3.775767e+06
# 3                                     262.663637               4.887542e+06
# 4                                     210.484576               4.646488e+06
#
#    Process_IO Data Operations_sec  Process_Pool Nonpaged Bytes  \
# 0                      293.825345                    2447032.0
# 1                      239.723175                    2451920.0
# 2                      694.779399                    2408264.0
# 3                      677.628039                    2318640.0
# 4                      753.786644                    2248992.0
#
#    Process_pct_ User_Time  Process_IO_Write Operations_sec  \
# 0              122.055019                       282.909543
# 1              118.289188                       230.722305
# 2               92.055880                       373.889746
# 3               95.612437                       296.474808
# 4               83.590059                       306.531906
#
#    Process_IO Read_Operations_sec  label
# 0                       10.915802    0.0
# 1                        9.000870    0.0
# 2                      320.889654    0.0
# 3                      381.153231    0.0
# 4                      447.254738    0.0

# %%
#Mention column name along with range
temp = df[(df['LogicalDisk(_Total) Free Megabytes'] >= 165000) & (df['LogicalDisk(_Total) Free Megabytes']<= 175000)]
#Mention Column name along with column index
df['LogicalDisk(_Total) Free Megabytes'] = temp.iloc[:,0]

#Mention column name along with range
temp = df[(df['LogicalDisk(_Total) pct_ Free Space'] >= 80) & (df['LogicalDisk(_Total) pct_ Free Space']<= 84)]
#Mention Column name along with column index
df['LogicalDisk(_Total) pct_ Free Space'] = temp.iloc[:,1]

#Mention column name along with range
temp = df[(df['Memory Pool Paged Resident Bytes'] >= .75*10**8) & (df['Memory Pool Paged Resident Bytes']<= 2*10**8)]
#Mention Column name along with column index
df['Memory Pool Paged Resident Bytes'] = temp.iloc[:,2]

#Mention column name along with range
temp = df[(df['Memory Committed Bytes'] >= 0.2*10**10) & (df['Memory Committed Bytes']<= 0.6*10**10)]
#Mention Column name along with column index
df['Memory Committed Bytes'] = temp.iloc[:,3]


#Mention column name along with range
temp = df[(df['Memory Standby Cache Core Bytes'] >= 1*10**8) & (df['Memory Standby Cache Core Bytes']<= 2.25*10**8)]
#Mention Column name along with column index
df['Memory Standby Cache Core Bytes'] = temp.iloc[:,4]


#Mention column name along with range
temp = df[(df['Memory Standby Cache Normal Priority Bytes'] >= 0) & (df['Memory Standby Cache Normal Priority Bytes']<= 0.5*10**9)]
#Mention Column name along with column index
df['Memory Standby Cache Normal Priority Bytes'] = temp.iloc[:,5]


df['Memory Long-Term Average Standby Cache Lifetime (s)'] = df['Memory Long-Term Average Standby Cache Lifetime (s)']

#Mention column name along with range
temp = df[(df['Memory Cache Bytes'] >= 0) & (df['Memory Cache Bytes']<= 2*10**8)]
#Mention Column name along with column index
df['Memory Cache Bytes'] = temp.iloc[:,7]

#Mention column name along with range
temp = df[(df['Network_I(Intel R _82574L_GNC) Bytes Sent sec'] >= 0) & (df['Network_I(Intel R _82574L_GNC) Bytes Sent sec']<= 100000)]
#Mention Column name along with column index
df['Network_I(Intel R _82574L_GNC) Bytes Sent sec'] = temp.iloc[:,8]


#Mention column name along with range
temp = df[(df['Process_IO Read Bytes_sec'] >= 0) & (df['Process_IO Read Bytes_sec']<= 2*10**7)]
#Mention Column name along with column index
df['Process_IO Read Bytes_sec'] = temp.iloc[:,9]

#Mention column name along with range
temp = df[(df['Process_IO Data Operations_sec'] >= 0) & (df['Process_IO Data Operations_sec']<= 10000)]
#Mention Column name along with column index
df['Process_IO Data Operations_sec'] = temp.iloc[:,10]


#Mention column name along with range
temp = df[(df['Process_Pool Nonpaged Bytes'] >= 0) & (df['Process_Pool Nonpaged Bytes']<= 4*10**6)]
#Mention Column name along with column index
df['Process_Pool Nonpaged Bytes'] = temp.iloc[:,11]


#Mention column name along with range
temp = df[(df['Process_pct_ User_Time'] >= 0) & (df['Process_pct_ User_Time']<= 100)]
#Mention Column name along with column index
df['Process_pct_ User_Time'] = temp.iloc[:,12]


#Mention column name along with range
temp = df[(df['Process_IO_Write Operations_sec'] >= 0) & (df['Process_IO_Write Operations_sec']<= 500)]
#Mention Column name along with column index
df['Process_IO_Write Operations_sec'] = temp.iloc[:,13]


#Mention column name along with range
temp = df[(df['Process_IO Read_Operations_sec'] >= 0) & (df['Process_IO Read_Operations_sec']<= 8000)]
#Mention Column name along with column index
df['Process_IO Read_Operations_sec'] = temp.iloc[:,14]

# %%
# import matplotlib.pyplot as plt
# columns = df.columns
# for col in columns:
#     print("col: ", col)
#     plt.scatter(df.index, df[col])
#     plt.show()

# %%
df.isnull().sum().sum()
# Out:
# 25933

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

x = df.drop('label', axis=1)
y = df['label']

model = RandomForestClassifier()
model.fit(x, y)

(pd.Series(model.feature_importances_, index=x.columns)
   # .nlargest(4)
   .plot(kind='barh',figsize = (5, 5) ))

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(df.corr(), annot=True, linewidth = 3, cmap='mako')
# Out:
# <AxesSubplot:>

# %%
df.drop('LogicalDisk(_Total) pct_ Free Space', axis = 1, inplace = True)

# %%
df_scaled = df

# %%
x_scaled = df_scaled.drop('label', axis=1)
y_scaled = df_scaled['label']

# %%
df_scaled.head(10)
# Out:
#     LogicalDisk(_Total) Free Megabytes  Memory Pool Paged Resident Bytes  \
# 2                             167984.0                        79081472.0
# 58                            167789.0                        75649024.0
# 59                            167789.0                        78942208.0
# 60                            167789.0                        81887232.0
# 61                            167789.0                        84430848.0
# 62                            167789.0                        90017792.0
# 63                            167789.0                        91901952.0
# 64                            167789.0                       102043648.0
# 65                            167789.0                       100126720.0
# 66                            167789.0                        94240768.0
#
#     Memory Committed Bytes  Memory Standby Cache Core Bytes  \
# 2             3.522941e+09                      113893376.0
# 58            3.156525e+09                      163835904.0
# 59            3.149775e+09                      163803136.0
# 60            3.157340e+09                      163770368.0
# 61            3.168883e+09                      163241984.0
# 62            3.168973e+09                      163225600.0
# 63            3.183190e+09                      163225600.0
# 64            3.179278e+09                      162885632.0
# 65            3.183841e+09                      162885632.0
# 66            3.189535e+09                      162893824.0
#
#     Memory Standby Cache Normal Priority Bytes  \
# 2                                   23834624.0
# 58                                  87298048.0
# 59                                  88109056.0
# 60                                  79532032.0
# 61                                  73543680.0
# 62                                  71020544.0
# 63                                  71024640.0
# 64                                  69582848.0
# 65                                  65732608.0
# 66                                  66048000.0
#
#     Memory Long-Term Average Standby Cache Lifetime (s)  Memory Cache Bytes  \
# 2                                                46.0            14024704.0
# 58                                               68.0            10297344.0
# 59                                               69.0            10911744.0
# 60                                               68.0            11735040.0
# 61                                               66.0            12251136.0
# 62                                               63.0            11264000.0
# 63                                               61.0             9953280.0
# 64                                               58.0            10588160.0
# 65                                               56.0            11550720.0
# 66                                               55.0            10989568.0
#
#     Network_I(Intel R _82574L_GNC) Bytes Sent sec  Process_IO Read Bytes_sec  \
# 2                                      209.808634               3.775767e+06
# 58                                     227.154148               3.518996e+04
# 59                                     242.996323               3.449038e+04
# 60                                     237.597537               3.392755e+04
# 61                                    1539.629711               2.957457e+04
# 62                                     248.786569               3.374313e+04
# 63                                     263.791382               3.596828e+04
# 64                                     243.371296               3.341959e+04
# 65                                     225.246700               3.565557e+04
# 66                                     254.899690               3.604226e+04
#
#     Process_IO Data Operations_sec  Process_Pool Nonpaged Bytes  \
# 2                       694.779399                    2408264.0
# 58                       97.351778                    2034952.0
# 59                       96.698537                    2035696.0
# 60                       92.399042                    2035248.0
# 61                       84.070572                    1948400.0
# 62                       91.442084                    1948960.0
# 63                      100.743946                    1950864.0
# 64                       95.746074                    1950832.0
# 65                       99.444022                    1950624.0
# 66                       99.299879                    1950480.0
#
#     Process_pct_ User_Time  Process_IO_Write Operations_sec  \
# 2                92.055880                       373.889746
# 58               34.741750                        47.073390
# 59               38.593336                        47.899275
# 60               37.030571                        46.199521
# 61               39.158494                        40.038360
# 62               42.409767                        45.670964
# 63               36.974123                        49.822823
# 64               40.373880                        47.672731
# 65               38.533394                        49.222794
# 66               38.125308                        49.699940
#
#     Process_IO Read_Operations_sec  label
# 2                       320.889654    0.0
# 58                       50.278387    0.0
# 59                       48.799262    0.0
# 60                       46.199521    0.0
# 61                       44.032212    0.0
# 62                       45.771120    0.0
# 63                       50.921122    0.0
# 64                       48.073342    0.0
# 65                       50.221228    0.0
# 66                       49.599940    0.0

# %%
x = df.drop('label', axis=1)
y = df['label']

# %%
x.head()
# Out:
#     LogicalDisk(_Total) Free Megabytes  Memory Pool Paged Resident Bytes  \
# 2                             167984.0                        79081472.0
# 58                            167789.0                        75649024.0
# 59                            167789.0                        78942208.0
# 60                            167789.0                        81887232.0
# 61                            167789.0                        84430848.0
#
#     Memory Committed Bytes  Memory Standby Cache Core Bytes  \
# 2             3.522941e+09                      113893376.0
# 58            3.156525e+09                      163835904.0
# 59            3.149775e+09                      163803136.0
# 60            3.157340e+09                      163770368.0
# 61            3.168883e+09                      163241984.0
#
#     Memory Standby Cache Normal Priority Bytes  \
# 2                                   23834624.0
# 58                                  87298048.0
# 59                                  88109056.0
# 60                                  79532032.0
# 61                                  73543680.0
#
#     Memory Long-Term Average Standby Cache Lifetime (s)  Memory Cache Bytes  \
# 2                                                46.0            14024704.0
# 58                                               68.0            10297344.0
# 59                                               69.0            10911744.0
# 60                                               68.0            11735040.0
# 61                                               66.0            12251136.0
#
#     Network_I(Intel R _82574L_GNC) Bytes Sent sec  Process_IO Read Bytes_sec  \
# 2                                      209.808634               3.775767e+06
# 58                                     227.154148               3.518996e+04
# 59                                     242.996323               3.449038e+04
# 60                                     237.597537               3.392755e+04
# 61                                    1539.629711               2.957457e+04
#
#     Process_IO Data Operations_sec  Process_Pool Nonpaged Bytes  \
# 2                       694.779399                    2408264.0
# 58                       97.351778                    2034952.0
# 59                       96.698537                    2035696.0
# 60                       92.399042                    2035248.0
# 61                       84.070572                    1948400.0
#
#     Process_pct_ User_Time  Process_IO_Write Operations_sec  \
# 2                92.055880                       373.889746
# 58               34.741750                        47.073390
# 59               38.593336                        47.899275
# 60               37.030571                        46.199521
# 61               39.158494                        40.038360
#
#     Process_IO Read_Operations_sec
# 2                       320.889654
# 58                       50.278387
# 59                       48.799262
# 60                       46.199521
# 61                       44.032212

# %% [markdown]
# # Without Oversampling

# %%
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=15, shuffle = True, random_state=3)

# %%
df.shape
# Out:
# (14456, 15)

# %%
# --------------------------Random Forest -----------------------------------
for train_index, test_index in skf.split(x, y):
    x_train, x_test, y_train, y_test = x.iloc[train_index], x.iloc[test_index], y.iloc[train_index], y.iloc[test_index]

from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_jobs=-1, bootstrap= False, criterion= 'gini', max_depth= 10, max_features= 2, min_samples_leaf= 2, n_estimators= 200)
rfc.fit(x_train, y_train) #Training the model
y_pred_rfc = rfc.predict(x_test)
# print(y_pred_rfc)# printing predictions

#Accuracy Score

from sklearn.model_selection import cross_val_score
scores = cross_val_score(rfc, x, y, cv=8)
print("Cross Validation Score Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

from sklearn.metrics import accuracy_score
rfcAccuracy = round(accuracy_score(y_test, y_pred_rfc)*100,2)
print("Accuracy of rfc: ",rfcAccuracy)

#F1 Score

from sklearn.metrics import f1_score
rfcF1 = round(f1_score(y_test, y_pred_rfc)*100,2)
print("f1_score of rfc: ",rfcF1)

#AUC Score

from sklearn.metrics import roc_auc_score
rfcAuc = round(roc_auc_score (y_test, y_pred_rfc)*100,2)
print('AUC Score of rfc:',rfcAuc)
# Out:
# Cross Validation Score Accuracy: 0.88 (+/- 0.22)
# Accuracy of rfc:  96.16
# f1_score of rfc:  96.68
# AUC Score of rfc: 95.83

# %%
from sklearn.model_selection import learning_curve
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

log_reg = rfc


train_sizes, train_scores, test_scores = learning_curve(estimator=log_reg,
                                                       X=x_train,
                                                       y=y_train,
                                                       train_sizes=np.linspace(0.1, 1.0, 10),
                                                       cv=15,
                                                       n_jobs=-1)

# Calculate the mean and standard deviation of the training scores
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

# Calculate the mean and standard deviation of the test scores
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Plot the learning curve
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training accuracy')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')

plt.plot(train_sizes, test_mean, color='green', linestyle='--', marker='s', markersize=5, label='Validation accuracy')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')

plt.grid()
plt.suptitle('RandomForestClassifier Learning Curve')
plt.xlabel('Number of training samples')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.ylim([0, 1.0])
plt.show()

# %%
#ROC CURVE:
from sklearn.metrics import roc_curve, auc, confusion_matrix

rfc_fpr, rfc_tpr, threshold = roc_curve(y_test, y_pred_rfc)
auc_rfc = auc(rfc_fpr, rfc_tpr)

plt.figure(figsize=(5, 5), dpi=100)
plt.plot(rfc_fpr, rfc_tpr, marker='.', label='Windows 10 rfc (auc = %0.3f)' % auc_rfc)

plt.xlabel('False Positive Rate -->')
plt.ylabel('True Positive Rate -->')

plt.legend()

plt.show()

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
import matplotlib.pyplot as plt
def plot(y_true, y_pred):
    labels = unique_labels(y_test)
    column = [f'Predicted{label}' for label in labels]
    indices = [f'Actual{label}' for label in labels]
    table = pd.DataFrame(confusion_matrix(y_true, y_pred), columns = column, index=indices)
    return sns.heatmap(table, annot = True, fmt = 'd', cmap = 'mako', ).set(title = 'RandomForestClassifier Confusion Matrix')

plot(y_test, y_pred_rfc)
# Out:
# [Text(0.5, 1.0, 'RandomForestClassifier Confusion Matrix')]

# %%
#!pip install interpret

# %%
from interpret.blackbox import LimeTabular
from interpret import show
# dtc = DecisionTreeClassifier()
# dtc.fit(x_train, y_train)
# y_pred = dtc.predict(x_test)
# print(f"F1 Score {f1_score(y_test, y_pred, average='macro')}")
# print(f"Accuracy {accuracy_score(y_test, y_pred)}")
# %% Apply lime
# Initilize Lime for Tabular data
lime = LimeTabular(predict_fn=rfc.predict_proba,
                   data=x_train,
                   random_state=1)
# Get local explanations
lime_local = lime.explain_local(x_test[:20],
                                y_test[:20],
                                name='LIME')
show(lime_local)
# Out:
#         <script type="text/javascript" src="https://unpkg.com/@interpretml/interpret-inline@0.3.0/dist/interpret-inline.js"></script>
#
#     <div id="_interpret-viz-83794676-1994-4cc9-8d38-3e49ee815a76"></div>
#     <script defer type="text/javascript">
#
#     (function universalLoad(root, callback) {
#       if(typeof exports === 'object' && typeof module === 'object') {
#         // CommonJS2
#         console.log("CommonJS2");
#         var interpretInline = require('interpret-inline');
#         callback(interpretInline);
#       } else if(typeof define === 'function' && define.amd) {
#         // AMD
#         console.log("AMD");
#         require(['interpret-inline'], function(interpretInline) {
#           callback(interpretInline);
#         });
#       } else if(typeof exports === 'object') {
#         // CommonJS
#         console.log("CommonJS");
#         var interpretInline = require('interpret-inline');
#         callback(interpretInline);
#       } else {
#         // Browser
#         console.log("Browser");
#         callback(root['interpret-inline']);
#       }
#     })(this, function(interpretInline) {
#         interpretInline.RenderApp("_interpret-viz-83794676-1994-4cc9-8d38-3e49ee815a76", {"name": "LIME", "overall": {"type": "none", "figure": "null", "help": {}}, "specific": [{"type": "plotly", "figure": {"data": [{"marker": {"color": ["#1f77b4", "#ff7f0e", "#1f77b4", "#ff7f0e", "#1f77b4", "#1f77b4", "#1f77b4", "#ff7f0e", "#1f77b4", "#1f77b4", "#808080"]}, "orientation": "h", "x": [-0.02076807730322639, 0.02209791600353688, -0.025651675732475142, 0.03558648440817074, -0.050285091272452086, -0.06055568139744146, -0.07011314759492443, 0.07672805885530161, -0.08670301897584629, -0.20180981285738347, 0.613071421030033], "y": ["Process_IO Read Bytes_sec (99398.66)", "Memory Standby Cache Normal Priority Bytes (108417024.00)", "Network_I(Intel R _82574L_GNC) Bytes Sent sec (247.63)", "Process_IO_Write Operations_sec (50.52)", "Memory Pool Paged Resident Bytes (90136576.00)", "Memory Committed Bytes (3212410880.00)", "Memory Long-Term Average Standby Cache Lifetime (s) (58.00)", "LogicalDisk(_Total) Free Megabytes (167323.00)", "Process_Pool Nonpaged Bytes (1953352.00)", "Memory Standby Cache Core Bytes (162664448.00)", "Intercept"], "type": "bar"}], "layout": {"title": {"text": "Actual: 0 | Predicted: 0.00932"}, "xaxis": {"range": [-0.613071421030033, 0.613071421030033], "title": {"text": ""}}, "yaxis": {"automargin": true, "dtick": 1, "title": {"text": ""}}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}, "pattern": {"fillmode": "overlay", "size": 10, "solidity": 0.2}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}, "pattern": {"fillmode": "overlay", "size": 10, "solidity": 0.2}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"pattern": {"fillmode": "overlay", "size": 10, "solidity": 0.2}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorba ...

# %%
# --------------------------Decision Tree -----------------------------------
for train_index, test_index in skf.split(x, y):
    x_train, x_test, y_train, y_test = x.iloc[train_index], x.iloc[test_index], y.iloc[train_index], y.iloc[test_index]

from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(x_train, y_train) #Training the model
y_pred_dtc = dtc.predict(x_test)
# print(y_pred_dtc)# printing predictions


#Accuracy Score

from sklearn.model_selection import cross_val_score
scores = cross_val_score(rfc, x, y, cv=8)
print("Cross Validation Score Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

from sklearn.metrics import accuracy_score
dtcAccuracy = round(accuracy_score(y_test, y_pred_dtc)*100,2)
print("Accuracy of Decisiontree: ",dtcAccuracy)

#F1 Score

from sklearn.metrics import f1_score
dtcF1 = round(f1_score(y_test, y_pred_dtc)*100,2)
print("f1_score of Decisiontree: ",dtcF1)

#AUC Score

from sklearn.metrics import roc_auc_score
dtcAuc = round(roc_auc_score (y_test, y_pred_dtc)*100,2)
print('AUC Score of Decision Tree:',dtcAuc)
# Out:
# Cross Validation Score Accuracy: 0.87 (+/- 0.24)
# Accuracy of Decisiontree:  94.6
# f1_score of Decisiontree:  95.26
# AUC Score of Decision Tree: 94.49

# %%
#ROC CURVE:
from sklearn.metrics import roc_curve, auc, confusion_matrix

dtc_fpr, dtc_tpr, threshold = roc_curve(y_test, y_pred_dtc)
auc_dtc = auc(dtc_fpr, dtc_tpr)

plt.figure(figsize=(5, 5), dpi=100)
plt.plot(dtc_fpr, dtc_tpr, marker='.', label='Windows 10 dtc (auc = %0.3f)' % auc_dtc)

plt.xlabel('False Positive Rate -->')
plt.ylabel('True Positive Rate -->')

plt.legend()

plt.show()

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
import matplotlib.pyplot as plt
def plot(y_true, y_pred):
    labels = unique_labels(y_test)
    column = [f'Predicted{label}' for label in labels]
    indices = [f'Actual{label}' for label in labels]
    table = pd.DataFrame(confusion_matrix(y_true, y_pred), columns = column, index=indices)
    return sns.heatmap(table, annot = True, fmt = 'd', cmap = 'mako', ).set(title = 'Decision Tree Confusion Matrix')

plot(y_test, y_pred_dtc)
# Out:
# [Text(0.5, 1.0, 'Decision Tree Confusion Matrix')]

# %%
from sklearn.model_selection import learning_curve
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

log_reg = dtc


train_sizes, train_scores, test_scores = learning_curve(estimator=log_reg,
                                                       X=x_train,
                                                       y=y_train,
                                                       train_sizes=np.linspace(0.1, 1.0, 10),
                                                       cv=15,
                                                       n_jobs=-1)

# Calculate the mean and standard deviation of the training scores
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

# Calculate the mean and standard deviation of the test scores
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Plot the learning curve
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training accuracy')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')

plt.plot(train_sizes, test_mean, color='green', linestyle='--', marker='s', markersize=5, label='Validation accuracy')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')

plt.grid()
plt.suptitle('Decision Learning Curve')
plt.xlabel('Number of training samples')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.ylim([0, 1.0])
plt.show()

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint
est = RandomForestClassifier(n_jobs=-1)
rf_p_dist={'max_depth':[3,5,10,None],
              'n_estimators':[10,100,200,300,400,500],
              'max_features':randint(1,15),
               'criterion':['gini','entropy'],
               'bootstrap':[True,False],
               'min_samples_leaf':randint(1,4),
              }
def hypertuning_rscv(est, p_distr, nbr_iter,x,y):
    rdmsearch = RandomizedSearchCV(est, param_distributions=p_distr,
                                  n_jobs=-1, n_iter=nbr_iter, cv=9)
    #CV = Cross-Validation ( here using Stratified KFold CV)
    rdmsearch.fit(x,y)
    ht_params = rdmsearch.best_params_
    ht_score = rdmsearch.best_score_
    return ht_params, ht_score

# %%
rf_parameters, rf_ht_score = hypertuning_rscv(est, rf_p_dist, 40, x, y)

# %%
print(rf_parameters)
print(rf_ht_score)
# Out:
# {'bootstrap': False, 'criterion': 'gini', 'max_depth': 10, 'max_features': 2, 'min_samples_leaf': 2, 'n_estimators': 200}
# 0.8931839557271102

# %%
classifier=RandomForestClassifier(n_jobs=-1, bootstrap= False, criterion= 'gini', max_depth= 10, max_features= 2, min_samples_leaf= 2, n_estimators= 200)

# %%
# Import necessary modules
from scipy.stats import randint
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV

# Setup the parameters and distributions to sample from: param_dist
param_dist = {"max_depth": [3, None],
              "max_features": randint(1, 9),
              "min_samples_leaf": randint(1, 9),
              "criterion": ["gini", "entropy"]}

# Instantiate a Decision Tree classifier: tree
tree = DecisionTreeClassifier()

# Instantiate the RandomizedSearchCV object: tree_cv
tree_cv = RandomizedSearchCV(tree, param_dist, cv=5)

# Fit it to the data
tree_cv.fit(x, y)

# Print the tuned parameters and score
print("Tuned Decision Tree Parameters: {}".format(tree_cv.best_params_))
print("Best score is {}".format(tree_cv.best_score_))
# Out:
# Tuned Decision Tree Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 4}
# Best score is 0.878871735767941

# %%
# --------------------------Decision Tree -----------------------------------
for train_index, test_index in skf.split(x, y):
    x_train, x_test, y_train, y_test = x.iloc[train_index], x.iloc[test_index], y.iloc[train_index], y.iloc[test_index]

from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(criterion= 'gini', max_depth= None, max_features= 1, min_samples_leaf= 4)
dtc.fit(x_train, y_train) #Training the model
y_pred_dtc = dtc.predict(x_test)
# print(y_pred_dtc)# printing predictions


#Accuracy Score

from sklearn.model_selection import cross_val_score
scores = cross_val_score(rfc, x, y, cv=8)
print("Cross Validation Score Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

from sklearn.metrics import accuracy_score
dtcAccuracy = round(accuracy_score(y_test, y_pred_dtc)*100,2)
print("Accuracy of Decisiontree: ",dtcAccuracy)

#F1 Score

from sklearn.metrics import f1_score
dtcF1 = round(f1_score(y_test, y_pred_dtc)*100,2)
print("f1_score of Decisiontree: ",dtcF1)

#AUC Score

from sklearn.metrics import roc_auc_score
dtcAuc = round(roc_auc_score (y_test, y_pred_dtc)*100,2)
print('AUC Score of Decision Tree:',dtcAuc)
# Out:
# Cross Validation Score Accuracy: 0.88 (+/- 0.23)
# Accuracy of Decisiontree:  94.91
# f1_score of Decisiontree:  95.54
# AUC Score of Decision Tree: 94.79

# %%
# from interpret.blackbox import LimeTabular
# from interpret import show
# # dtc = DecisionTreeClassifier()
# # dtc.fit(x_train, y_train)
# # y_pred = dtc.predict(x_test)
# # print(f"F1 Score {f1_score(y_test, y_pred, average='macro')}")
# # print(f"Accuracy {accuracy_score(y_test, y_pred)}")
# # %% Apply lime
# # Initilize Lime for Tabular data
# lime = LimeTabular(predict_fn=dtc.predict_proba,
#                    data=x_train,
#                    random_state=1)
# # Get local explanations
# lime_local = lime.explain_local(x_test[-200:],
#                                 y_test[-200:],
#                                 name='LIME')
# show(lime_local)

# %%
# --------------------------KNN -----------------------------------
for train_index, test_index in skf.split(x, y):
    x_train, x_test, y_train, y_test = x.iloc[train_index], x.iloc[test_index], y.iloc[train_index], y.iloc[test_index]

from sklearn.preprocessing import MinMaxScaler
scaler= MinMaxScaler()
#fit scaler to train set, it will learn parameters
scaler.fit(x_train)
#transform train and test sets
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

#converting from numpy
x_train= pd.DataFrame(x_train_scaled, columns=x_train.columns)
x_test= pd.DataFrame(x_test_scaled, columns=x_test.columns)

from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=13, p=3)
knn.fit(x_train, y_train) #Training the model
y_pred_knn = knn.predict(x_test)
# print(y_pred_knn)# printing predictions

#Accuracy Score

from sklearn.metrics import accuracy_score
knnAccuracy = round(accuracy_score(y_test, y_pred_knn)*100,2)
print("Accuracy of KNN: ",knnAccuracy)

#F1 Score

from sklearn.metrics import f1_score
knnF1 = round(f1_score(y_test, y_pred_knn)*100,2)
print("f1_score of KNN: ",knnF1)

#AUC Score

from sklearn.metrics import roc_auc_score
knnAuc = round(roc_auc_score (y_test, y_pred_knn)*100,2)
print('AUC Score of KNN:',knnAuc)
# Out:
# Accuracy of KNN:  95.33
# f1_score of KNN:  95.96
# AUC Score of KNN: 95.01

# %%
#ROC CURVE:
from sklearn.metrics import roc_curve, auc, confusion_matrix

knn_fpr, knn_tpr, threshold = roc_curve(y_test, y_pred_knn)
auc_knn = auc(knn_fpr, knn_tpr)

plt.figure(figsize=(5, 5), dpi=100)
plt.plot(knn_fpr, knn_tpr, marker='.', label='Windows 10 knn (auc = %0.3f)' % auc_knn)

plt.xlabel('False Positive Rate -->')
plt.ylabel('True Positive Rate -->')

plt.legend()

plt.show()

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
import matplotlib.pyplot as plt
def plot(y_true, y_pred):
    labels = unique_labels(y_test)
    column = [f'Predicted{label}' for label in labels]
    indices = [f'Actual{label}' for label in labels]
    table = pd.DataFrame(confusion_matrix(y_true, y_pred), columns = column, index=indices)
    return sns.heatmap(table, annot = True, fmt = 'd', cmap = 'mako', ).set(title = 'K-Nearest Neighbour Confusion Matrix')

plot(y_test, y_pred_knn)
# Out:
# [Text(0.5, 1.0, 'K-Nearest Neighbour Confusion Matrix')]

# %%
from sklearn.model_selection import learning_curve
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

log_reg = knn

train_sizes, train_scores, test_scores = learning_curve(estimator=log_reg,
                                                       X=x_train,
                                                       y=y_train,
                                                       train_sizes=np.linspace(0.1, 1.0, 10),
                                                       cv=15,
                                                       n_jobs=-1)

# Calculate the mean and standard deviation of the training scores
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

# Calculate the mean and standard deviation of the test scores
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Plot the learning curve
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training accuracy')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')

plt.plot(train_sizes, test_mean, color='green', linestyle='--', marker='s', markersize=5, label='Validation accuracy')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')

plt.grid()
plt.suptitle('K-Nearest Neighbour Learning Curve')
plt.xlabel('Number of training samples')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.ylim([0, 1.0])
plt.show()

# %%
# from interpret.blackbox import LimeTabular
# from interpret import show
# # dtc = DecisionTreeClassifier()
# # dtc.fit(x_train, y_train)
# # y_pred = dtc.predict(x_test)
# # print(f"F1 Score {f1_score(y_test, y_pred, average='macro')}")
# # print(f"Accuracy {accuracy_score(y_test, y_pred)}")
# # %% Apply lime
# # Initilize Lime for Tabular data
# lime = LimeTabular(predict_fn=knn.predict_proba,
#                    data=x_train,
#                    random_state=1)
# # Get local explanations
# lime_local = lime.explain_local(x_test[50:100],
#                                 y_test[50:100],
#                                 name='LIME')
# show(lime_local)

# %%
#--------------------Logistic Regression ------------------------
for train_index, test_index in skf.split(x, y):
    x_train, x_test, y_train, y_test = x.iloc[train_index], x.iloc[test_index], y.iloc[train_index], y.iloc[test_index]

from sklearn.preprocessing import MinMaxScaler
scaler= MinMaxScaler()
#fit scaler to train set, it will learn parameters
scaler.fit(x_train)
#transform train and test sets
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

#converting from numpy
x_train= pd.DataFrame(x_train_scaled, columns=x_train.columns)
x_test= pd.DataFrame(x_test_scaled, columns=x_test.columns)

lr = LogisticRegression(class_weight="balanced")


lr.fit(x_train, y_train) #Training the model
y_pred_lr = lr.predict(x_test)
# print(y_pred_lr)# printing predictions


#Accuracy Score

from sklearn.model_selection import cross_val_score
scores = cross_val_score(rfc, x, y, cv=15)
print("Cross Validation Score Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))


from sklearn.metrics import accuracy_score
lrAccuracy = round(accuracy_score(y_test, y_pred_lr)*100,2)
print("Accuracy of LR: ",lrAccuracy)

#F1 Score

from sklearn.metrics import f1_score
lrF1 = round(f1_score(y_test, y_pred_lr)*100,2)
print("f1_score of LR: ",lrF1)

#AUC Score

from sklearn.metrics import roc_auc_score
lrAuc = round(roc_auc_score (y_test, y_pred_lr)*100,2)
print('AUC Score of LR:',lrAuc)
# Out:
# Cross Validation Score Accuracy: 0.87 (+/- 0.25)
# Accuracy of LR:  85.15
# f1_score of LR:  87.11
# AUC Score of LR: 84.69

# %%
#ROC CURVE:
from sklearn.metrics import roc_curve, auc, confusion_matrix

lr_fpr, lr_tpr, threshold = roc_curve(y_test, y_pred_lr)
auc_lr = auc(lr_fpr, lr_tpr)

plt.figure(figsize=(5, 5), dpi=100)
plt.plot(lr_fpr, lr_tpr, marker='.', label='Windows 10 lr (auc = %0.3f)' % auc_lr)

plt.xlabel('False Positive Rate -->')
plt.ylabel('True Positive Rate -->')

plt.legend()

plt.show()

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
import matplotlib.pyplot as plt
def plot(y_true, y_pred):
    labels = unique_labels(y_test)
    column = [f'Predicted{label}' for label in labels]
    indices = [f'Actual{label}' for label in labels]
    table = pd.DataFrame(confusion_matrix(y_true, y_pred), columns = column, index=indices)
    return sns.heatmap(table, annot = True, fmt = 'd', cmap = 'mako', ).set(title = 'Logistic Regression Confusion Matrix')

plot(y_test, y_pred_lr)
# Out:
# [Text(0.5, 1.0, 'Logistic Regression Confusion Matrix')]

# %%
from sklearn.model_selection import learning_curve
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

log_reg = LogisticRegression()


train_sizes, train_scores, test_scores = learning_curve(estimator=log_reg,
                                                       X=x_train,
                                                       y=y_train,
                                                       train_sizes=np.linspace(0.1, 1.0, 10),
                                                       cv=15,
                                                       n_jobs=-1)

# Calculate the mean and standard deviation of the training scores
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

# Calculate the mean and standard deviation of the test scores
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Plot the learning curve
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training accuracy')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')

plt.plot(train_sizes, test_mean, color='green', linestyle='--', marker='s', markersize=5, label='Validation accuracy')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')

plt.grid()
plt.suptitle('LogisticRegression Learning Curve')
plt.xlabel('Number of training samples')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.ylim([0, 1.0])
plt.show()

# %%
# from interpret.blackbox import LimeTabular
# from interpret import show
# # dtc = DecisionTreeClassifier()
# # dtc.fit(x_train, y_train)
# # y_pred = dtc.predict(x_test)
# # print(f"F1 Score {f1_score(y_test, y_pred, average='macro')}")
# # print(f"Accuracy {accuracy_score(y_test, y_pred)}")
# # %% Apply lime
# # Initilize Lime for Tabular data
# lime = LimeTabular(predict_fn=knn.predict_proba,
#                    data=x_train,
#                    random_state=1)
# # Get local explanations
# lime_local = lime.explain_local(x_test[50:100],
#                                 y_test[50:100],
#                                 name='LIME')
# show(lime_local)

# %%
# from sklearn.datasets import make_blobs
# from sklearn.model_selection import RepeatedStratifiedKFold
# from sklearn.model_selection import GridSearchCV
# from sklearn.linear_model import LogisticRegression

# X, y = make_blobs(n_samples=1000, centers=2, n_features=100, cluster_std=20)
# # define models and parameters
# model = LogisticRegression()
# solvers = ['newton-cg', 'lbfgs', 'liblinear']
# penalty = ['l2']
# c_values = [100, 10, 1.0, 0.1, 0.01]

# # define grid search
# grid = dict(solver=solvers,penalty=penalty,C=c_values)
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
# grid_result = grid_search.fit(X, y)
# # summarize results
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# means = grid_result.cv_results_['mean_test_score']
# stds = grid_result.cv_results_['std_test_score']
# params = grid_result.cv_results_['params']
# for mean, stdev, param in zip(means, stds, params):
#     print("%f (%f) with: %r" % (mean, stdev, param))

# %%
#Plotting a bar graph to compare the accuracy scores of the different scoring metrics
dtc_scores = [dtcAccuracy, dtcF1, dtcAuc]
rfc_scores = [rfcAccuracy, rfcF1, rfcAuc]
KNN_scores = [knnAccuracy, knnF1, knnAuc]
LR_scores = [lrAccuracy, lrF1, lrAuc]

x_labels = ['Accuracy', 'F1 Score', 'AUC Score']

def autolabel(rectangle_group):
    for rect in rectangle_group:
        height = rect.get_height()

        ax.annotate(str(height), xy = (rect.get_x(), height+.19))

width = 0.17

x_dtc = [x-width for x in range (len(dtc_scores))]
x_rfc = [x for x in range (len(rfc_scores))]
x_KNN = [x+width for x in range (len(KNN_scores))]
x_LR = [x+(2*width) for x in range (len(LR_scores))]


fig,ax = plt.subplots(figsize = (10, 6))
rect1 = ax.bar(x_dtc ,dtc_scores, width, label='Decision Tree', color = 'pink', edgecolor='black')
rect2 = ax.bar(x_rfc, rfc_scores, width, label='Random Forest', color='cyan', edgecolor='black')
rect3 = ax.bar(x_KNN, KNN_scores, width, label='KNN', color='lightgreen', edgecolor='black')
rect4 = ax.bar(x_LR, LR_scores, width, label='Logistic Regression', color='silver', edgecolor='black')

plt.xticks([x for x in range(len(x_labels))], x_labels)
ax.set_title('Windows10')
ax.set_xlabel('Models')
ax.set_ylabel('Score %')
plt.ylim([70, 105])
ax.legend()

autolabel(rect1)
autolabel(rect2)
autolabel(rect3)
autolabel(rect4)
plt.show()

# %%
#ROC CURVE:
from sklearn.metrics import roc_curve, auc, confusion_matrix

rfc_fpr, rfc_tpr, threshold = roc_curve(y_test, y_pred_rfc)
auc_rfc = auc(rfc_fpr, rfc_tpr)

dtc_fpr, dtc_tpr, threshold = roc_curve(y_test, y_pred_dtc)
dtc_rfc = auc(dtc_fpr, dtc_tpr)

lr_fpr, lr_tpr, threshold = roc_curve(y_test, y_pred_dtc)
lr_rfc = auc(lr_fpr, lr_tpr)

knn_fpr, knn_tpr, threshold = roc_curve(y_test, y_pred_dtc)
knn_rfc = auc(knn_fpr, knn_tpr)

plt.figure(figsize=(5, 5), dpi=100)
plt.plot(rfc_fpr, rfc_tpr, marker='.', label='Windows 10 RFC (auc = %0.3f)' % auc_rfc)
plt.xlabel('False Positive Rate -->')
plt.ylabel('True Positive Rate -->')
plt.legend()

plt.plot(dtc_fpr, dtc_tpr, marker='.', label='Windows 10 DTC (auc = %0.3f)' % auc_dtc)
plt.xlabel('False Positive Rate -->')
plt.ylabel('True Positive Rate -->')
plt.legend()

plt.plot(lr_fpr, dtc_tpr, marker='.', label='Windows 10 LR (auc = %0.3f)' % auc_lr )
plt.xlabel('False Positive Rate -->')
plt.ylabel('True Positive Rate -->')
plt.legend()

plt.plot(knn_fpr, knn_tpr, marker='.', label='Windows 10 KNN (auc = %0.3f)' % auc_knn )

plt.xlabel('False Positive Rate -->')
plt.ylabel('True Positive Rate -->')

plt.legend()

plt.show()
